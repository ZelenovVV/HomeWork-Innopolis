# %% [markdown]
# **Задача.** Взять датасет (Титаник) и отрисовать его в одном из видов баз данных.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Загрузка датасета

# %%
url = 'https://drive.google.com/file/d/16MAuRsO7t_0hjWJPp4YN7cojyo3TA60p/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id=' + url.split('/')[-2]
TitanicDB = pd.read_csv(path)
TitanicDB.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 2. Для начала отрисуем датасет в виде стандартной реляционной базы данных.

# %% [markdown]
# Первоначально можно представить наш датасет в виде двух таблиц Passengers и Ticket
#
# ![Titanic_relatio.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Но далее необходимо привести наш датасет к нормализации, заодно добавив дополнительную информацию, например добавим кроме обозначения порта посадки Embarked и названия порта - Port_Name, так же разделим некоторые ячейки на несколько - отдельно укажем имя, второе имя, фамилию, вынесем отдельную таблицу с девичьими именами (Old Names), отдельную таблицу с обращениями Appesls (это мисс, миссис, мистер и т.д.), отдельную таблицу для класса круиза Pclasses (по идее у каждого класса должно быть название или номер, описани и т.д.). Так же с учетом указания Survived в виде 0/1, необходимо вывести таблицу Survivors с описанием Survived_Status (Невыжил/Выжил) к Survived_ID (0/1). Структура датасета может выглядеть примерно так:
#
# ![Titanic_relatio+.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 3. Изобразим для сравнения наш датасет в виде колоночной базы данных.

# %% [markdown]
# При построении колоночной базы данных необходимо учитывать, что каждая строка может иметь свой набор свойств, что позволяет хранить разно структурированные данные:
#
# ![Titanic colomn.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Например, для пассажира с PassengerID 2 указаны девичье имя (OldName) и каюта (Cabin). Эти данные отсутствуют у пассажиров 1 и 3.
